# %% [markdown]
# # Python for Data Science

# %% [markdown]
# ## Python
#
# - Multi-platform
# - Interpreted / Dynamic Typing
# - Garbage Collected
# - Object-Oriented & Procedural
# - **Large Standard Library**
#
# Created by [Guido van Rossum](https://www.linkedin.com/in/guido-van-rossum-4a0756/), first released in **1991**

# %% [markdown]
# ### REPL
#
# Read, Eval, Print, Loop.
#
# Open your terminal and launch:
#
# ```bash
# ipython
# ```

# %% [markdown]
# ## Documentation
#
# 👉 [The Python 3.12 Standard Library](https://docs.python.org/3.12/library/index.html)

# %% [markdown]
# ## Built-in Types
#
# Let's look at the important sections of the [documentation](https://docs.python.org/3.12/library/stdtypes.html) and explore the **simple** built-in types.

# %% [markdown]
# ### [Numeric Types](https://docs.python.org/3.12/library/stdtypes.html#numeric-types-int-float-complex)

# %%
type(42)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
4 + 9.5
# Out:
# 13.5

# %%
abs(-5)
# Out:
# 5

# %% [markdown]
# ### [Booleans](https://docs.python.org/3.12/library/stdtypes.html#truth-value-testing)

# %%
type(True) # or type(False)
# Out:
# bool

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ### What are falsy values in Python?
#
#
# - Constants defined to be false: `None` and `False`.
# - Zero of any numeric type: `0`, `0.0`, etc.
# - Empty sequences and collections: `''`, `()`, `[]`, `{}`, `set()`, `range(0)`

# %% [markdown]
# ### Comparisons

# %%
5 < 3 # Strictly less than
# Out:
# False

# %%
4 <= 4 # Less than or equal
# Out:
# True

# %%
"boris" == "seb" # equal, note the `double` =
# Out:
# False

# %%
"boris" != "seb" # not equal
# Out:
# True

# %% [markdown]
# ### Text Sequence Type (Strings, `str`)

# %%
"boris"
# Out:
# 'boris'

# %%
"boris".capitalize()
# Out:
# 'Boris'

# %%
"   boris ".strip()
# Out:
# 'boris'

# %%
type(int("42"))
# Out:
# int

# %% [markdown]
# Check out the [documentation](https://docs.python.org/3.12/library/stdtypes.html#string-methods) for more `str` methods.

# %% [markdown]
# ## Advanced built-in types

# %% [markdown]
# ### Sequence Types
#
# - [`list`](https://docs.python.org/3.12/library/stdtypes.html#list)
# - [`tuple`](https://docs.python.org/3.12/library/stdtypes.html#tuple)
# - [`range`](https://docs.python.org/3.12/library/stdtypes.html#range)

# %% [markdown]
# ### An example of `list`

# %%
["apple", "cherries", "banana"]
# Out:
# ['apple', 'cherries', 'banana']

# %%
len(["apple", "cherries", "banana"])
# Out:
# 3

# %%
"banana" in ["apple", "cherries", "banana"]
# Out:
# True

# %% [markdown]
# ### Mapping Type
#
# There is just one in Python, `dict` (read dictionary)

# %%
{'city': 'Paris', 'population': 2_141_000}
# Out:
# {'city': 'Paris', 'population': 2141000}

# %%
len({'city': 'Paris', 'population': 2_141_000})
# Out:
# 2

# %%
'city' in {'city': 'Paris', 'population': 2_141_000}
# Out:
# True

# %% [markdown]
# ## Variables

# %%
name = 'John' # Assignment
print(name)
# Out:
# John

# %%
name = 'Paul' # Re-assignment
print(name)
# Out:
# Paul

# %%
first_name = 'John'
last_name = 'Lennon'

# %%
full_name = first_name + last_name
print(full_name)
# Out:
# JohnLennon

# %% [markdown]
# ### String Formatting - Interpolation

# %%
sentence = f'Hi, my name is {first_name} {last_name}'
print(sentence)
# Out:
# Hi, my name is John Lennon

# %% [markdown]
# ## `list` operations

# %%
# Indexes:    0       1       2
beatles = ['john', 'paul', 'ringo']

# %%
beatles[0] # Read
# Out:
# 'john'

# %%
beatles.append('george') # Create (in place)
print(beatles)
# Out:
# ['john', 'paul', 'ringo', 'george']

# %%
beatles[1] = 'Paul' # Update (in place)
print(beatles)
# Out:
# ['john', 'Paul', 'ringo', 'george']

# %% [markdown]
# ### Other `list` operations

# %%
beatles
# Out:
# ['john', 'Paul', 'ringo', 'george']

# %%
beatles[1:3] # Slice of 1 to 3 (excluded)
# Out:
# ['Paul', 'ringo']

# %%
del beatles[1] # Delete (in place)
print(beatles)
# Out:
# ['john', 'ringo', 'george']

# %% [markdown]
# ## `dict` operations

# %%
instruments = {'john':'guitar', 'paul':'bass'} # Keys are `str`, Values too

# %%
instruments['john'] # Read
# Out:
# 'guitar'

# %%
instruments['ringo'] = 'drums' # Create / Update
print(instruments)
# Out:
# {'john': 'guitar', 'paul': 'bass', 'ringo': 'drums'}

# %%
del instruments['john']
instruments
# Out:
# {'paul': 'bass', 'ringo': 'drums'}

# %% [markdown]
# ### Other `dict` operation

# %%
instruments
# Out:
# {'paul': 'bass', 'ringo': 'drums'}

# %% [markdown]
# What will happen if we run `instruments['john']`?

# %%
instruments['john']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 instruments['john']
#
# KeyError: 'john'

# %%
instruments.get('john', 'Default instrument')
# Out:
# 'Default instrument'

# %% [markdown]
# ## Control Flow
#
# Once again, the documentation is very [thorough](https://docs.python.org/3.12/tutorial/controlflow.html)

# %% [markdown]
# ### `if` statement

# %%
age = int(input("How old are you?"))

if age >= 21:
    print("You can become president")
elif age >= 18:
    print("You can vote")
else:
    print("Be patient!")
# Out:
# You can vote

# %% [markdown]
# ### `for` statement (on a `list`)

# %%
words = ['cat', 'wolf', 'beetle']
for word in words:
    print(word.upper())
# Out:
# CAT
# WOLF
# BEETLE

# %% [markdown]
# ### List comprehension
# You can achieve the same result in just one line:

# %%
[print(word.upper()) for word in words]
# Out:
# CAT
# WOLF
# BEETLE
# [None, None, None]

# %% [markdown]
# ...or store it in a new variable:

# %%
uppercase_words = [word.upper() for word in words]
print(uppercase_words)
# Out:
# ['CAT', 'WOLF', 'BEETLE']

# %% [markdown]
# What if you need the index inside the `for` loop?

# %%
for index, word in enumerate(words):
    print(index, word)
# Out:
# 0 cat
# 1 wolf
# 2 beetle

# %% [markdown]
# ### `for` statement (on a `dict`)

# %%
instruments
# Out:
# {'paul': 'bass', 'ringo': 'drums'}

# %%
for beatle, instrument in instruments.items():
    print(f'{beatle.capitalize()} plays the {instrument}')
# Out:
# Paul plays the bass
# Ringo plays the drums

# %% [markdown]
# ### `while` loop

# %%
i = 1
while i <= 4:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Functions
#
# Let's see how we can [define and use our own functions](https://docs.python.org/3.12/tutorial/controlflow.html#defining-functions).

# %%
def is_even(number):
    return number % 2 == 0

# %% [markdown]
# - The function is named `is_even`
# - The function takes **1** parameter: `number` (`int`)
# - The function returns a `bool`

# %%
result = is_even(42)
print(result)
# Out:
# True

# %% [markdown]
# We called the function with the **argument** `42`. The returned value is stored in a `result` variable.

# %% [markdown]
# ### Keyword Arguments
#
# Let's have a look at [`pandas.DataFrame.from_dict`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html) ([Source](https://github.com/pandas-dev/pandas/blob/v1.0.3/pandas/core/frame.py#L1168-L1247)). Some arguments are passed with the syntax `parameter=value`.

# %%
def is_odd(number=0):
    return number % 2 == 1

# %%
result = is_odd(number=1)
print(result)
# Out:
# True

# %% [markdown]
# ### Mixing positional and keyword arguments

# %%
def full_name(first_name, last_name, capitalize=False):
    if capitalize:
        return f"{first_name.capitalize()} {last_name.capitalize()}"
    else:
        return f"{first_name} {last_name}"

# %%
print(full_name("john", "lennon"))
print(full_name("ringo", "starr", capitalize=True))
# Out:
# john lennon
# Ringo Starr

# %% [markdown]
# ## [Modules](https://docs.python.org/3.12/tutorial/modules.html)
#
# As our programs will grow longer, we will want to split the code into many files & folders.
#
# Here is a very simple example to illustrate this technique:

# %% [markdown]
# ```bash
# mkdir project && cd project
# touch app.py
# mkdir helpers && touch helpers/__init__.py
# ```

# %%
# helpers/__init__.py
import random
import string

def generate_password(size):
    """Generate a random lowercase ASCII password of given size"""
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(size))

# %%
# app.py
from helpers import generate_password # Module import here

print(generate_password(16))
# Out:
# qegvpctubmfsyash

# %% [markdown]
# ```bash
# python app.py
# ```

# %% [markdown]
# Before you go, one more thing!
#
#
# ## Debugging 🐛

# %% [markdown]
# - `print(your_variable)`
# - `ipython`
# - `python <file_name>`

# %% [markdown]
# When running your code with `python <file_name>` you can use the <a href="https://ipython.readthedocs.io/en/stable/" target="_blank">IPython debugger (ipdb)</a> thanks to the built-in [`breakpoint()`](https://docs.python.org/3/library/functions.html#breakpoint) function.
#
# It will let you investigate the current state of your code.

# %% [markdown]
# Let's try with our `generate_password` function!

# %% [markdown]
# Add the debugger in the function definition and run the `app.py` file from the Terminal.

# %%
# helpers/__init__.py
import random
import string

def generate_password(size, upper=False):
    """Generate a random lowercase ASCII password of given size"""
    letters = string.ascii_uppercase if upper else string.ascii_lowercase
    breakpoint()
    return ''.join(random.choice(letters) for i in range(size))

# %% [markdown]
# You can access the `args`, variables defined within the function (`letters`) and much more: just type the name of the variable and hit ENTER.
#
# To see the part of the code you're at, type `list` (or just `l`).
#
# To continue the execution try:
#
# * `next` (or just `n`) - execute the current line and go to the next line
# * `step` (or just `s`) - step into the next function that will be called
# * `continue` (or just `c`) - continue until the next `breakpoint()`, or the end
#
# If you want to see all available commands type `help` (or just `h`).

# %% [markdown]
# ### Tips from TAs ❤️

# %% [markdown]
# #### Read the instructions!

# %% [markdown]
# #### It's OK not to finish all challenges
#
# #### Pseudocode first!
# Programming is all about going step by step, decomposing hard problems into small ones.
#
# ✒️ Write down the steps you'll need to code in plain English.
#
# Separate 🤔 thinking about the ⚙️ logic from getting the `["syntax')}` exactly right.
#
# #### Run your code!
# ‼️ Don't try to `make` directly.
# ```python
# # example.py
# def my_function(param1, param2):
#     # BODY
#     # BODY
#     # BODY
#     return # SOMETHING
#
# print(my_function(arg1, arg2)) # <- Temp code to test! Remove before final commit/push
# ```
# and then run the code in your terminal:
#
# ```bash
# python example.py
# ```
#
# #### Debug your code!
# Poor man's way: `print()` all the things! What's the type of this variable? What does it contain at this point of the program?
#
#
# Better: debug your code using `breakpoint()`!
#
#
#
# 💪 **Debugging** is one of the most important skills to master in your career!

# %% [markdown]
# ## Advanced Language Topics
#
# To master Python, here are some additional topics to dive into during the Bootcamp:
#
# - [List Comprehensions](https://treyhunner.com/2015/12/python-list-comprehensions-now-in-color/)
# - [Memory Management / Garbage Collection](https://docs.python.org/3/faq/design.html?highlight=garbage%20collector#how-does-python-manage-memory)
# - [Object Oriented Programming](https://anandology.com/python-practice-book/object_oriented_programming.html)
# - [`*args` & `**kwargs`](https://www.digitalocean.com/community/tutorials/how-to-use-args-and-kwargs-in-python-3)
# - [Iterators & Generators](https://anandology.com/python-practice-book/iterators.html)

# %% [markdown]
# ## Your turn!
#
# Head onto Kitt, find your **buddy** and start your first challenge!
#
# Remember:
# - Read the assignment **carefully**
# - Run your code with `python <file.py>` before running `make`
# - Talk with your buddy
# - Raise a **ticket** 🙋‍♀️
#
# Have fun! 🚀
