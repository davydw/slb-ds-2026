# %% [markdown]
# # Kickstarter campaign analysis

# %% [markdown]
# We start by importing all necessary packages.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt

# %% [markdown]
# The max_column settings have been increased to allow for viewing all the columns in the initial sample overview further below.

# %% [markdown]
# Next we import the data and take a quick look at the contents.

# %%
kickstarter_df = pd.read_csv('https://wagon-public-datasets.s3.amazonaws.com/02-Data-Toolkit/01-Data-Analysis/18k_Projects.csv', decimal=',', dtype={22:str, 23: str, 27:str})
kickstarter_df.head(5)
# Out:
#            Id                                               Name  \
# 0  1007121454  Nail Art and Photos Printed on your Nails w/ E...
# 1  2032015036                                         Cold Again
# 2   733782855                                 Uchu Bijin Jewelry
# 3   514687871  Poetically Speaking: Stories of Love, Triumph ...
# 4   683545993  Stranger Travels: Teachings from the Heart of ...
#
#                                                  Url   State Currency  \
# 0  https://www.kickstarter.com/projects/137019948...  failed      USD
# 1  https://www.kickstarter.com/projects/737783165...  failed      USD
# 2  https://www.kickstarter.com/projects/uchubijin...  failed      USD
# 3  https://www.kickstarter.com/projects/tylicee/p...  failed      USD
# 4  https://www.kickstarter.com/projects/197270300...  failed      USD
#
#    Top Category    Category           Creator  Location  Updates  Comments  \
# 0           Art         Art       Dodie Egolf  Puyallup        0         0
# 1  Film & Video  Short Film      James Jacobs    Boston        0         0
# 2       Fashion     Fashion        Uchu Bijin  New York        1         2
# 3    Publishing      Poetry  Tylicee Mysreign   Detroit        0         0
# 4    Publishing  Nonfiction      Ian Driscoll  Pucallpa        0         0
#
#    Rewards   Goal  Pledged  Backers       Start         End  Duration in Days  \
# 0        9  20000        6        2  2013/12/15  2014/01/14                30
# 1        8   3000      180        5  2013/12/15  2014/01/17                33
# 2       17   5000     1941       62  2013/12/15  2014/01/14                30
# 3        4   5000      130        5  2013/12/15  2014/02/13                60
# 4       12  12000     1015       16  2013/12/15  2014/01/14                30
#
#   Facebook Connected  Facebook Friends  Facebook Shares Has Video  \
# 0                Yes             272.0               70       Yes
# 1                Yes             573.0               57       Yes
# 2                 No               NaN              158        No
# 3                Yes            1285.0                2       Yes
# 4                Yes             969.0              411       Yes
#
#         Latitude        Longitude    Start Timestamp (UTC)  \
# 0  47.1803951263  -122.2529029846  2013/12/15 01:53:49.000
# 1  42.3323383331   -71.0456199646  2013/12/15 02:30:01.000
# 2   40.706577301   -73.8823738098  2013/12/15 01:29:42.000
# 3  42.3546390533   -83.1028404236  2013/12/15 01:12:28.000
# 4       -8.43381        -74.55957  2013/12/15 01:17:46.000
#
#        End Timestamp (UTC)                                     Creator Bio  \
# 0  2014/01/14 01:53:49.000  https://www.kickstarter.com/profile/1370199487
# 1  2014/01/17 02:30:01.000   https://www.kickstarter.com/profile/737783165
# 2  2014/01/14 01:29:42.000   https://www.kickstarter.com/profile/858150887
# 3  2014/02/13 01:12:28.000  https://www.kickstarter.com/profile/1079088465
# 4  2014/01/14 01:17:46.000  https://www.kickstarter.com/profile/1972703001
#
#                                     Creator Website  \
# 0                                               NaN
# 1                                               NaN
# 2                              http://uchubijin.com
# 3  http://www.linkedin.com/pub/mys-reign/1a/469/4a8
# 4              http://strangertravels.wordpress.com
#
#    Creator - # Projects Created  Creator - # Projects Backed  # Videos  \
# 0                             1                          0.0       0.0
# 1                             1                          4.0       0.0
# 2                             2                          2.0       0.0
# 3                             1                          2.0       0.0
# 4                             1                          0.0       0.0
#
#    # Images  # Words (Description)  # Words (Risks and Challenges)  # FAQs
# 0         2                    297                           153.0       0
# 1         0                    276                            98.0       0
# 2        12                   1049                            66.0       2
# 3         0                    309                           169.0       0
# 4         6                   1636                           216.0       0

# %% [markdown]
# There is alot of interesting data here. State is probably something we want to look at. Possibly also duration in days, goal vs pledge, number of backers and categories.

# %% [markdown]
# What are the dimensions of the data set in rows and columns?

# %%
kickstarter_df.shape
# Out:
# (18142, 35)

# %% [markdown]
# What are the columns and their data types?

# %%
kickstarter_df.dtypes
# Out:
# Id                                  int64
# Name                               object
# Url                                object
# State                              object
# Currency                           object
# Top Category                       object
# Category                           object
# Creator                            object
# Location                           object
# Updates                             int64
# Comments                            int64
# Rewards                             int64
# Goal                                int64
# Pledged                             int64
# Backers                             int64
# Start                              object
# End                                object
# Duration in Days                    int64
# Facebook Connected                 object
# Facebook Friends                  float64
# Facebook Shares                     int64
# Has Video                          object
# Latitude                           object
# Longitude                          object
# Start Timestamp (UTC)              object
# End Timestamp (UTC)                object
# Creator Bio                        object
# Creator Website                    object
# Creator - # Projects Created        int64
# Creator - # Projects Backed       float64
# # Videos                          float64
# # Images                            int64
# # Words (Description)               int64
# # Words (Risks and Challenges)    float64
# # FAQs                              int64
# dtype: object

# %% [markdown]
# Basic statistics about numerical columns look as follows.

# %%
kickstarter_df.describe()
# Out:
#                  Id       Updates      Comments       Rewards          Goal  \
# count  1.814200e+04  18142.000000  18142.000000  18142.000000  1.814200e+04
# mean   1.073471e+09      3.368647     34.243027     10.042002  2.653121e+04
# std    6.181166e+08      5.547975    539.161283      5.889806  7.583874e+05
# min    1.061440e+05      0.000000      0.000000      2.000000  1.000000e+02
# 25%    5.385158e+08      0.000000      0.000000      6.000000  2.000000e+03
# 50%    1.078580e+09      1.000000      0.000000      9.000000  5.000000e+03
# 75%    1.606254e+09      5.000000      3.000000     12.000000  1.500000e+04
# max    2.147445e+09    128.000000  30341.000000    131.000000  1.000000e+08
#
#             Pledged       Backers  Duration in Days  Facebook Friends  \
# count  1.814200e+04  18142.000000      18142.000000      12290.000000
# mean   1.102364e+04    138.070279         31.398468        694.233686
# std    7.855300e+04    633.787780         10.058827        783.802343
# min    1.000000e+00      1.000000          1.000000          0.000000
# 25%    2.600000e+02      7.000000         29.000000        216.250000
# 50%    1.722000e+03     29.000000         30.000000        453.000000
# 75%    6.335000e+03     89.000000         32.000000        860.000000
# max    6.224955e+06  35383.000000         60.000000       4885.000000
#
#        Facebook Shares  Creator - # Projects Created  \
# count     18142.000000                  18142.000000
# mean        396.729137                      1.520119
# std        2544.711314                      2.540474
# min           0.000000                      1.000000
# 25%          21.000000                      1.000000
# 50%         104.000000                      1.000000
# 75%         322.000000                      1.000000
# max      260505.000000                    111.000000
#
#        Creator - # Projects Backed      # Videos      # Images  \
# count                 13898.000000  18041.000000  18142.000000
# mean                      5.149950      0.226207      6.898302
# std                      20.351979      0.877530     10.272907
# min                       0.000000      0.000000      0.000000
# 25%                       0.000000      0.000000      0.000000
# 50%                       1.000000      0.000000      3.000000
# 75%                       4.000000      0.000000     10.000000
# max                    1205.000000     24.000000    166.000000
#
#        # Words (Description)  # Words (Risks and Challenges)        # FAQs
# count           18142.000000                    18041.000000  18142.000000
# mean              668.056278                      130.330359      0.679032
# std               582.136947                       96.989659      2.045969
# min                 3.000000                        8.000000      0.000000
# 25%               276.000000                       69.000000      0.000000
# 50%               490.000000                      105.000000      0.000000
# 75%               871.750000                      163.000000      0.000000
# max              5152.000000                     1888.000000     47.000000

# %% [markdown]
# We may be interested to know the completeness of the data, as shown below.

# %%
kickstarter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18142 entries, 0 to 18141
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Id                              18142 non-null  int64
#  1   Name                            18142 non-null  object
#  2   Url                             18142 non-null  object
#  3   State                           18142 non-null  object
#  4   Currency                        18142 non-null  object
#  5   Top Category                    18142 non-null  object
#  6   Category                        18142 non-null  object
#  7   Creator                         18142 non-null  object
#  8   Location                        18142 non-null  object
#  9   Updates                         18142 non-null  int64
#  10  Comments                        18142 non-null  int64
#  11  Rewards                         18142 non-null  int64
#  12  Goal                            18142 non-null  int64
#  13  Pledged                         18142 non-null  int64
#  14  Backers                         18142 non-null  int64
#  15  Start                           18142 non-null  object
#  16  End                             18142 non-null  object
#  17  Duration in Days                18142 non-null  int64
#  18  Facebook Connected              18142 non-null  object
#  19  Facebook Friends                12290 non-null  float64
#  20  Facebook Shares                 18142 non-null  int64
#  21  Has Video                       18142 non-null  object
#  22  Latitude                        9803 non-null   object
#  23  Longitude                       9803 non-null   object
#  24  Start Timestamp (UTC)           18142 non-null  object
#  25  End Timestamp (UTC)             18142 non-null  object
#  26  Creator Bio                     18142 non-null  object
#  27  Creator Website                 11475 non-null  object
#  28  Creator - # Projects Created    18142 non-null  int64
#  29  Creator - # Projects Backed     13898 non-null  float64
#  30  # Videos                        18041 non-null  float64
#  31  # Images                        18142 non-null  int64
#  32  # Words (Description)           18142 non-null  int64
#  33  # Words (Risks and Challenges)  18041 non-null  float64
#  34  # FAQs                          18142 non-null  int64
# dtypes: float64(4), int64(13), object(18)
# memory usage: 4.8+ MB

# %% [markdown]
# It may be easier to get an appreciation of what data is missing

# %%
null_df = kickstarter_df.isnull().sum()
#null_df.columns = ['column', 'missing']
#null_df = null_df[null_df['missing'] > 0]
null_df
# Out:
# Id                                   0
# Name                                 0
# Url                                  0
# State                                0
# Currency                             0
# Top Category                         0
# Category                             0
# Creator                              0
# Location                             0
# Updates                              0
# Comments                             0
# Rewards                              0
# Goal                                 0
# Pledged                              0
# Backers                              0
# Start                                0
# End                                  0
# Duration in Days                     0
# Facebook Connected                   0
# Facebook Friends                  5852
# Facebook Shares                      0
# Has Video                            0
# Latitude                          8339
# Longitude                         8339
# Start Timestamp (UTC)                0
# End Timestamp (UTC)                  0
# Creator Bio                          0
# Creator Website                   6667
# Creator - # Projects Created         0
# Creator - # Projects Backed       4244
# # Videos                           101
# # Images                             0
# # Words (Description)                0
# # Words (Risks and Challenges)     101
# # FAQs                               0
# dtype: int64

# %% [markdown]
# It would be convenient to have a column for funding in %.

# %%
kickstarter_df['Funding%'] = kickstarter_df['Pledged'] / kickstarter_df['Goal']
kickstarter_df['Success'] = (kickstarter_df['State'] != 'failed').astype(int)
kickstarter_df.head()
# Out:
#            Id                                               Name  \
# 0  1007121454  Nail Art and Photos Printed on your Nails w/ E...
# 1  2032015036                                         Cold Again
# 2   733782855                                 Uchu Bijin Jewelry
# 3   514687871  Poetically Speaking: Stories of Love, Triumph ...
# 4   683545993  Stranger Travels: Teachings from the Heart of ...
#
#                                                  Url   State Currency  \
# 0  https://www.kickstarter.com/projects/137019948...  failed      USD
# 1  https://www.kickstarter.com/projects/737783165...  failed      USD
# 2  https://www.kickstarter.com/projects/uchubijin...  failed      USD
# 3  https://www.kickstarter.com/projects/tylicee/p...  failed      USD
# 4  https://www.kickstarter.com/projects/197270300...  failed      USD
#
#    Top Category    Category           Creator  Location  Updates  Comments  \
# 0           Art         Art       Dodie Egolf  Puyallup        0         0
# 1  Film & Video  Short Film      James Jacobs    Boston        0         0
# 2       Fashion     Fashion        Uchu Bijin  New York        1         2
# 3    Publishing      Poetry  Tylicee Mysreign   Detroit        0         0
# 4    Publishing  Nonfiction      Ian Driscoll  Pucallpa        0         0
#
#    Rewards   Goal  Pledged  Backers       Start         End  Duration in Days  \
# 0        9  20000        6        2  2013/12/15  2014/01/14                30
# 1        8   3000      180        5  2013/12/15  2014/01/17                33
# 2       17   5000     1941       62  2013/12/15  2014/01/14                30
# 3        4   5000      130        5  2013/12/15  2014/02/13                60
# 4       12  12000     1015       16  2013/12/15  2014/01/14                30
#
#   Facebook Connected  Facebook Friends  Facebook Shares Has Video  \
# 0                Yes             272.0               70       Yes
# 1                Yes             573.0               57       Yes
# 2                 No               NaN              158        No
# 3                Yes            1285.0                2       Yes
# 4                Yes             969.0              411       Yes
#
#         Latitude        Longitude    Start Timestamp (UTC)  \
# 0  47.1803951263  -122.2529029846  2013/12/15 01:53:49.000
# 1  42.3323383331   -71.0456199646  2013/12/15 02:30:01.000
# 2   40.706577301   -73.8823738098  2013/12/15 01:29:42.000
# 3  42.3546390533   -83.1028404236  2013/12/15 01:12:28.000
# 4       -8.43381        -74.55957  2013/12/15 01:17:46.000
#
#        End Timestamp (UTC)                                     Creator Bio  \
# 0  2014/01/14 01:53:49.000  https://www.kickstarter.com/profile/1370199487
# 1  2014/01/17 02:30:01.000   https://www.kickstarter.com/profile/737783165
# 2  2014/01/14 01:29:42.000   https://www.kickstarter.com/profile/858150887
# 3  2014/02/13 01:12:28.000  https://www.kickstarter.com/profile/1079088465
# 4  2014/01/14 01:17:46.000  https://www.kickstarter.com/profile/1972703001
#
#                                     Creator Website  \
# 0                                               NaN
# 1                                               NaN
# 2                              http://uchubijin.com
# 3  http://www.linkedin.com/pub/mys-reign/1a/469/4a8
# 4              http://strangertravels.wordpress.com
#
#    Creator - # Projects Created  Creator - # Projects Backed  # Videos  \
# 0                             1                          0.0       0.0
# 1                             1                          4.0       0.0
# 2                             2                          2.0       0.0
# 3                             1                          2.0       0.0
# 4                             1                          0.0       0.0
#
#    # Images  # Words (Description)  # Words (Risks and Challenges)  # FAQs  \
# 0         2                    297                           153.0       0
# 1         0                    276                            98.0       0
# 2        12                   1049                            66.0       2
# 3         0                    309                           169.0       0
# 4         6                   1636                           216.0       0
#
#    Funding%  Success
# 0  0.000300        0
# 1  0.060000        0
# 2  0.388200        0
# 3  0.026000        0
# 4  0.084583        0

# %% [markdown]
# Based on all of the above information we may now select a limited number of columns for use in our analysis.

# %%
kickstarter_df = kickstarter_df[['Name', 'Top Category', 'Category', 'Goal', 'Currency', 'Funding%', 'Success', 'Backers', 'Duration in Days']]
kickstarter_df.head()
# Out:
#                                                 Name  Top Category  \
# 0  Nail Art and Photos Printed on your Nails w/ E...           Art
# 1                                         Cold Again  Film & Video
# 2                                 Uchu Bijin Jewelry       Fashion
# 3  Poetically Speaking: Stories of Love, Triumph ...    Publishing
# 4  Stranger Travels: Teachings from the Heart of ...    Publishing
#
#      Category   Goal Currency  Funding%  Success  Backers  Duration in Days
# 0         Art  20000      USD  0.000300        0        2                30
# 1  Short Film   3000      USD  0.060000        0        5                33
# 2     Fashion   5000      USD  0.388200        0       62                30
# 3      Poetry   5000      USD  0.026000        0        5                60
# 4  Nonfiction  12000      USD  0.084583        0       16                30

# %% [markdown]
# Let's determine how many projects there are in each top category and how many succeeded.

# %%
success_df = kickstarter_df.groupby(['Top Category']).sum()[['Success']]
success_df['Total'] = kickstarter_df.groupby(['Top Category']).count()[['Success']]
success_plot = success_df.plot(kind='bar')
success_plot.set_ylabel('Projects')
# Out:
# Text(0, 0.5, 'Projects')

# %% [markdown]
# We may also want to know the total successes and total number of projects.

# %%
total_success_df = kickstarter_df[['Success']].sum()
total_success_df['Total'] = kickstarter_df.shape[0]
total_success_plot = total_success_df.plot(kind='bar')
total_success_plot.set_ylabel('Projects')
# Out:
# Text(0, 0.5, 'Projects')

# %% [markdown]
# We may be interested in the success rate for each genre from most to least successful. We also include one bar for any category.

# %%
success_rate_df = success_df['Success'] / success_df['Total']
success_rate_df.loc['* Any category *'] = kickstarter_df['Success'].sum() / kickstarter_df.shape[0]
plot = success_rate_df.sort_values(ascending=False).plot(kind='bar')
plot.set_ylabel('Success Rate')
# Out:
# Text(0, 0.5, 'Success Rate')
