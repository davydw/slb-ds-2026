# %% [markdown]
# # 🛠️ Use these newly created functions

# %%
from supermath.fancy_mathematics import sum_of_three_numbers

# %%
sum_of_three_numbers(10,20,30)
# Out:
# 60

# %%
from supermath.fancy_mathematics import product_of_three_numbers

# %%
product_of_three_numbers(3,4,-1)
# Out:
# -12

# %%
from greetings.hello import gutenmorgen

# %%
gutenmorgen("davy")
# Out:
# 'Hello Davy'

# %%
from greetings.shangrila.food import parrot

# %%
parrot()
# Out:
# 'Are you still hungry ?'

# %%
a = 2026

# %%
a == 2027-1
# Out:
# True

# %%
a != 2027-1
# Out:
# False

# %%
assert a == 2027-1

# %%
assert a != 2027-1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 assert a != 2027-1
#
# AssertionError:
