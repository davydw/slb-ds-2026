# %%
def sum_of_three_numbers(a, b, c):
    return a + b + c

# %%
sum_of_three_numbers(1, 2, 3)
# Out:
# 6

# %%
def product_of_three_numbers(a,b,c):
    return a * b * c

# %%
product_of_three_numbers(2, 4, 10)
# Out:
# 80
