# %% [markdown]
# # Coding Properly

# %% [markdown]
# ## Why?

# %% [markdown]
# ## What we'll cover

# %% [markdown]
# ## Moving code to `.py` files

# %% [markdown]
# ### Why?

# %% [markdown]
# * We'll write more and more code
# * Things will get messy if we don't pay attention
# * You actually spend more time reading code than writing code
#     * Others' code
#     *  Your own code
#
# In this unit, we'll also use `git` in a proper way

# %% [markdown]
# ## What we'll cover

# %% [markdown]
# * From notebook to `.py` files
# * Testing and TDD
# * OOP - Object Objected Programming
# * Coding style
# * Documenting code
# * Typing hinting
# * Good `git commit` practices

# %% [markdown]
# ## Moving code to `.py` files:

# %% [markdown]
# ### Why?

# %% [markdown]
# ### 🎯 Our task: calculate the Manhattan distance

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Why tests?

# %% [markdown]
# ### TDD: Test-Driven Development

# %% [markdown]
# ### 🎯 Our nest task: the Euclidean distance, the TDD way!

# %% [markdown]
# ### Benefits of TDD

# %% [markdown]
# ## OOP

# %% [markdown]
# ### OOP?

# %% [markdown]
# ### Have you already practiced OOP?

# %% [markdown]
# ### Why OOP?

# %% [markdown]
# ### Classes and Instances

# %% [markdown]
# ### Class Methods

# %% [markdown]
# ### Next up: we want to create Data (science) students!

# %% [markdown]
# ### Class inheritance

# %% [markdown]
# ### Multiple files

# %% [markdown]
# ### Let's recap

# %% [markdown]
# ## Coding style

# %% [markdown]
# ### Good style matters

# %% [markdown]
# ### An example

# %% [markdown]
# ### What's wrong?

# %% [markdown]
# ### Better

# %% [markdown]
# ### "Official" rules/guidelines

# %% [markdown]
# ### Assistants for coding style

# %% [markdown]
# #### Formatters

# %% [markdown]
# #### Linting

# %% [markdown]
# ### In practice

# %% [markdown]
# ## Documenting code

# %% [markdown]
# ## Type hinting

# %% [markdown]
# ## Automating

# %% [markdown]
# ##
