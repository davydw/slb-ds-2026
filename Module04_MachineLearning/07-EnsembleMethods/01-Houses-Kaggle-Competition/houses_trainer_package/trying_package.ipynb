# %%
from houses_trainer.trainer import Trainer

# %%
slb_trainer = Trainer()
slb_trainer

# %%
slb_trainer.load_data()
# Out:
# ---- loading data... ----
# ---- X shape: (1460, 80) ----

# %%
slb_trainer.build_pipeline(
    feature_cutoff_percentage=75
)
# Out:
# ---- preprocessing... ----
# ---- X shape: (1460, 162) ----

# %%
slb_trainer.cross_validate(cv=5)
# Out:
# ---- cross validate 5 folds----
# Mean RMSLE: 0.11797968602052826 /n Standard Dev : 0.01152895603374311
