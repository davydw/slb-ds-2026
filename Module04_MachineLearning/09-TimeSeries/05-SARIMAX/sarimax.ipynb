# %% [markdown]
# # SARIMAX on electricity carbon intensity

# %% [markdown]
# The website [**electricitymap.org**](https://electricitymap.org) provides real-time data-viz about the origin of electricity consumed around the world. In particular, it provides hourly view of the CO2-intensity of electricity in grams of CO2-equivalent per kWh electricity consumed (gCO2e/kWh).

# %% [markdown]
# <img src='electricitymap.jpg' width = 500>

# %% [markdown]
# Carbon intensity flucutates a lot depending on seasons, weather conditions, imports from neighbors countries, etc...
#
# Your goal is to **forecast the hourly carbon intensity of electricity in France up to 48 hours ahead** so as to inform when is best to consumer electricity (e.g. charge electric car)

# %% [markdown]
# ## Challenge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
# Load the 50Mo CSV!
df = pd.read_csv('https://wagon-public-datasets.s3.amazonaws.com/electricity_map_france.csv', parse_dates=['datetime'], index_col=['datetime'])
df = df['2016':]
df.fillna(method='bfill', inplace=True)
# Out:
# /var/folders/6p/s5dyg_x13_zbgfd_xsyg3s7c0000gn/T/ipykernel_94272/2137508044.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 32691 entries, 2016-01-01 00:00:00+00:00 to 2019-09-26 08:00:00+00:00
# Data columns (total 72 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   timestamp                                     32691 non-null  int64
#  1   zone_name                                     32691 non-null  object
#  2   carbon_intensity_avg                          32691 non-null  float64
#  3   carbon_intensity_production_avg               32691 non-null  float64
#  4   carbon_intensity_discharge_avg                32691 non-null  float64
#  5   carbon_intensity_import_avg                   32691 non-null  float64
#  6   carbon_rate_avg                               32691 non-null  float64
#  7   total_production_avg                          32691 non-null  float64
#  8   total_storage_avg                             32691 non-null  float64
#  9   total_discharge_avg                           32691 non-null  float64
#  10  total_import_avg                              32691 non-null  float64
#  11  total_export_avg                              32691 non-null  float64
#  12  total_consumption_avg                         32691 non-null  float64
#  13  production_sources                            32691 non-null  object
#  14  power_origin_percent_fossil_avg               32691 non-null  float64
#  15  power_origin_percent_renewable_avg            32691 non-null  float64
#  16  power_production_biomass_avg                  32691 non-null  float64
#  17  power_production_coal_avg                     32691 non-null  float64
#  18  power_production_gas_avg                      32691 non-null  float64
#  19  power_production_hydro_avg                    32691 non-null  float64
#  20  power_production_nuclear_avg                  32691 non-null  float64
#  21  power_production_oil_avg                      32691 non-null  float64
#  22  power_production_solar_avg                    32691 non-null  float64
#  23  power_production_wind_avg                     32691 non-null  float64
#  24  power_production_geothermal_avg               0 non-null      float64
#  25  power_production_unknown_avg                  0 non-null      float64
#  26  power_consumption_biomass_avg                 32691 non-null  float64
#  27  power_consumption_coal_avg                    32691 non-null  float64
#  28  power_consumption_gas_avg                     32691 non-null  float64
#  29  power_consumption_hydro_avg                   32691 non-null  float64
#  30  power_consumption_nuclear_avg                 32691 non-null  float64
#  31  power_consumption_oil_avg                     32691 non-null  float64
#  32  power_consumption_solar_avg                   32691 non-null  float64
#  33  power_consumption_wind_avg                    32691 non-null  float64
#  34  power_consumption_geothermal_avg              32691 non-null  float64
#  35  power_consumption_unknown_avg                 32691 non-null  float64
#  36  power_consumption_hydro_discharge_avg         32691 non-null  float64
#  37  carbon_origin_percent_biomass_avg             32691 non-null  float64
#  38  carbon_origin_percent_coal_avg                32691 non-null  float64
#  39  carbon_origin_percent_gas_avg                 32691 non-null  float64
#  40  carbon_origin_percent_hydro_avg               32691 non-null  float64
#  41  carbon_origin_percent_nuclear_avg             32691 non-null  float64
#  42  carbon_origin_percent_oil_avg                 32691 non-null  float64
#  43  carbon_origin_percent_solar_avg               32691 non-null  float64
#  44  carbon_origin_percent_wind_avg                32691 non-null  float64
#  45  carbon_origin_percent_geothermal_avg          32691 non-null  float64
#  46  carbon_origin_percent_unknown_avg             32691 non-null  float64
#  47  carbon_origin_percent_hydro_discharge_avg     32691 non-null  float64
#  48  power_net_discharge_hydro_avg                 32691 non-null  float64
#  49  power_net_import_BE_avg                       32691 non-null  float64
#  50  power_net_import_CH_avg                       32691 non-null  float64
#  51  power_net_import_DE_avg                       32691 non-null  float64
#  52  power_net_import_ES_avg                       32691 non-null  float64
#  53  power_net_import_GB_avg                       32691 non-null  float64
#  54  power_net_import_IT-NO_avg                    32691 non-null  float64
#  55  latest_forecasted_dewpoint_avg                32691 non-null  float64
#  56  latest_forecasted_precipitation_avg           32691 non-null  float64
#  57  latest_forecasted_solar_avg                   32691 non-null  float64
#  58  latest_forecasted_temperature_avg             32691 non-null  float64
#  59  latest_forecasted_wind_x_avg                  32691 non-null  float64
#  60  latest_forecasted_wind_y_avg                  32691 non-null  float64
#  61  latest_forecasted_price_avg                   32691 non-null  float64
#  62  latest_forecasted_production_avg              32691 non-null  float64
#  63  latest_forecasted_consumption_avg             32691 non-null  float64
#  64  latest_forecasted_power_net_import_BE_avg     32691 non-null  float64
#  65  latest_forecasted_power_net_import_CH_avg     32691 non-null  float64
#  66  latest_forecasted_power_net_import_DE_avg     32691 non-null  float64
#  67  latest_forecasted_power_net_import_ES_avg     32691 non-null  float64
#  68  latest_forecasted_power_net_import_GB_avg     32691 non-null  float64
#  69  latest_forecasted_power_net_import_IT-NO_avg  32691 non-null  float64
#  70  latest_forecasted_production_solar_avg        32691 non-null  float64
#  71  latest_forecasted_production_wind_avg         32691 non-null  float64
# dtypes: float64(69), int64(1), object(2)
# memory usage: 18.2+ MB

# %%
# We provide you with this method for fast plotting
def plot_autocorrelation(y, d=0, D=0, m=0):
    y = pd.Series(y)
    if D > 0:
        for i in range(D):
            y = y.diff(m)
    if d > 0:
        for i in range(d):
            y = y.diff(1)
    fig = plt.figure(figsize=(20,10))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,2,3)
    ax3 = fig.add_subplot(2,2,4)
    ax1.plot(y)
    plot_acf(y, lags = 50, ax=ax2);
    plot_pacf(y, lags=50, method='ywm', ax=ax3, color='r');
    plt.show()

# %% [markdown]
# ### Your challenge
# - Your goal is to predict `carbon_intensity_avg` up to 48h ahead.
# - We have 6 years of data at hourly granularity! Enough to make proper `cross_validated` score of `mape` over the whole dataset!
# - You have access to exogeneous forecast prefixed by `latest_forecasted_`
#     - e.g. you can use `latest_forecasted_price_avg(t+i)` when trying to predict `carbon_intensity_avg(t+i)`
#     - for i in [1..48]

# %% [markdown]
# ### Hints

# %% [markdown]
# - You can build a `SARMIAX` model with `exog` features
# - Or, you can build your own "traditional" ML-based model, optimizing for the 48h ahead time horizon

# %% [markdown]
# ## Your turn

# %%
train_size = 0.7
index = round(train_size*df.shape[0])
df_train = df.iloc[:index]
df_test = df.iloc[index+1:]

y = df['carbon_intensity_avg']
y_train = df_train['carbon_intensity_avg']
y_test = df_test['carbon_intensity_avg']

exog = df['latest_forecasted_price_avg']
exog_train = df_train['latest_forecasted_price_avg']
exog_test = df_test['latest_forecasted_price_avg']

# %%
# %matplotlib widget
# %matplotlib inline

y.plot()
df.latest_forecasted_price_avg.plot();

# %%
plt.plot(y['2018-02']);

# %%
plt.plot(y['2018-02'].diff(1));

# %%
plt.plot(y['2018-02'].diff(24*7));

# %%
plot_autocorrelation(y_train['2018-02-01':'2018-04-01'], D=0, m=168)

# %%
import pmdarima as pm
sarimax = pm.auto_arima(y_train, exogenous=exog_train,
                           start_p=2, start_q=2,
                           test='adf',
                           max_p=3, max_q=3, m=24,
                           start_P=0, seasonal=True,
                           d=None, D=None, trace=True,
                           suppress_warnings=True,
                           stepwise=False, n_jobs=-1,
                           random=True, random_state=42)
# Out:
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=218006.085, Time=0.31 sec
#  ARIMA(0,0,2)(0,0,0)[24] intercept   : AIC=166407.760, Time=4.97 sec
#  ARIMA(2,0,3)(0,0,0)[24] intercept   : AIC=114425.842, Time=7.48 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=171101.202, Time=32.04 sec
#  ARIMA(2,0,1)(0,0,1)[24] intercept   : AIC=112246.274, Time=45.92 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : AIC=157368.513, Time=49.97 sec
#  ARIMA(0,0,0)(1,0,1)[24] intercept   : AIC=183308.980, Time=51.33 sec
#  ARIMA(1,0,3)(0,0,1)[24] intercept   : AIC=112240.039, Time=57.47 sec
#  ARIMA(2,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=78.27 sec
#  ARIMA(0,0,2)(1,0,1)[24] intercept   : AIC=142741.156, Time=97.97 sec
#
# Best model:  ARIMA(1,0,3)(0,0,1)[24] intercept
# Total fit time: 109.001 seconds

# %%
predict_48 = sarimax.predict(n_periods=48, exogenous=exog_test[:48])
# Out:
# /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
plt.plot(predict_48, label='predict')
plt.plot(y_test[:48], label='real')

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test[:48], predict_48)
# Out:
# 0.24031521057707195
