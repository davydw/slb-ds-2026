# %% [markdown]
# # 05-MachineLearning-08-UnsupervisedLearning-2-Flashcards.ipynb

# %% [markdown]
# <details>
#   <summary>Clustering is a supervised learning method that groups data points. True or False?</summary>
#
# False! Clustering is an UNSUPERVISED learning method that groups data points.
# </details>

# %% [markdown]
# <details>
#   <summary>How does PCA function in mathematical terms?</summary>
#
# It works by finding the eigenvectors and eigenvalues of the covariance matrix. Eigenvectors give the direction and eigenvalues indicate the variance of the data explained by a component.
# </details>

# %% [markdown]
# <details>
#   <summary>What is unsupervised learning?</summary>
#
# The goal of unsupervised learning algorithms is to find patterns within the features without a known target
# </details>

# %% [markdown]
# <details>
#   <summary>Name a dimensionality reduction technique you learnt today?</summary>
#
# Principal Component Analysis.
# </details>

# %% [markdown]
# <details>
#   <summary>What technique would you use to reduce the dimensionality of an image?</summary>
#
# You can use the PCA to reduce the dimensionality of an image.
#
# Another possibility is to use a K-means algorithm. The number of clusters K will correspond to the number of dimensions you want your original image to be compressed to.
# </details>

# %% [markdown]
# <details>
#   <summary>How would you go about finding out the optimal number of clusters for your K-mean algorithm?
#
# </summary>
#
# You can use an elbow method with a distance metric of the points assigned to their respective clusters (i.e. sum of squared distances).
# </details>

# %% [markdown]
# <details>
#   <summary>What are the iterative steps of the K-means algorithm?</summary>
#
# 1. Choose the number of clusters K to look for
# 2. Initialize K centroids at random
# 3. Compute the mean square distance between each data point and each centroid
# 4. Assign each data point to the closest centroid (a cluster is formed)
# 5. Compute the mean $\mu_{j}$ of each cluster, the result of which becomes your new centroid
# </details>

# %% [markdown]
# <details>
#   <summary>What does PCA stand for and what is it?</summary>
#
# PCA stands for Principal Component Analysis. It’s a way to explain our matrix X by finding a K-dimensional orthogonal projection that preserves the greatest variance.
# </details>

# %% [markdown]
# <details>
#   <summary>What are the eigenvectors of Principal Component Analysis?</summary>
#
# An eigenvector is a vector whose direction remains unchanged when a linear transformation is applied to it.
# </details>

# %% [markdown]
# <details>
#   <summary>What is the K-means algorithm?</summary>
#
# The K-means algorithm is an iterative unsupervised learning algorithm that tries to partition the dataset into K pre-defined distinct non-overlapping subgroups (clusters) where each data point belongs to only one group.
#
#
# </details>

# %% [markdown]
# <details>
#   <summary>In image data, what are the components of each pixel?</summary>
#
# There are three components to each pixel, corresponding to the RGB colors.
# </details>
