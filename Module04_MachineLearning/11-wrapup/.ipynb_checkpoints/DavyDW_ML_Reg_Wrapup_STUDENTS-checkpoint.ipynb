# %% [markdown]
# # Machine Learning Wrapup - Regression

# %% [markdown]
# ## Libraries

# %%
# DATA MANIPULATION
import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np
import datetime

# STATS
from statsmodels.graphics.gofplots import qqplot

# DATA VISUALISATION
import matplotlib.pyplot as plt
import seaborn as sns

# ML
## PREPROC
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_selector
# METRICS
from sklearn.metrics import r2_score, mean_squared_error
## MODEL
#### BASIC MODELS
###### LINEAR MODELS
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
###### ADVANCED MODELS
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## Airbnb Prices (Regression)

# %% [markdown]
# ### Dataset

# %% [markdown]
# #### Loading

# %%
airbnb_asheville = "https://wagon-public-datasets.s3.amazonaws.com/data-science-images/05-ML/Reboot-2/asheville_airbnb.csv"

# %%
df = pd.read_csv(airbnb_asheville, index_col = 0)
df
# Out:
#       neighbourhood_cleansed  latitude  longitude          property_type  \
# 0                      28801  35.60670  -82.55563     Entire rental unit
# 1                      28806  35.57864  -82.59578      Entire guesthouse
# 2                      28806  35.57864  -82.59578   Private room in home
# 3                      28806  35.57864  -82.59578  Shared room in hostel
# 4                      28806  35.57808  -82.63689   Private room in home
# ...                      ...       ...        ...                    ...
# 2851                   28806  35.61922  -82.65641              Camper/RV
# 2852                   28732  35.42588  -82.57732      Entire guesthouse
# 2853                   28806  35.61355  -82.66020     Entire guest suite
# 2854                   28806  35.61215  -82.66623           Entire cabin
# 2855                   28806  35.64122  -82.64693           Entire cabin
#
#             room_type  accommodates    bathrooms_text  bedrooms  beds  \
# 0     Entire home/apt             2            1 bath       1.0   1.0
# 1     Entire home/apt             2            1 bath       1.0   1.0
# 2        Private room             2  2.5 shared baths       1.0   1.0
# 3         Shared room             1  2.5 shared baths       1.0   6.0
# 4        Private room             2    1 private bath       1.0   1.0
# ...               ...           ...               ...       ...   ...
# 2851  Entire home/apt             2            1 bath       NaN   1.0
# 2852  Entire home/apt             2            1 bath       NaN   1.0
# 2853  Entire home/apt             4            1 bath       1.0   2.0
# 2854  Entire home/apt             6           2 baths       3.0   3.0
# 2855  Entire home/apt             4         1.5 baths       1.0   1.0
#
#         price  minimum_nights  number_of_reviews  review_scores_rating  \
# 0     $120.00              30                 90                  4.50
# 1     $100.00               1                359                  4.58
# 2      $66.00               1                 67                  4.52
# 3      $33.00               1                306                  4.71
# 4      $45.00               2                 51                  4.98
# ...       ...             ...                ...                   ...
# 2851   $30.00               1                 39                  4.54
# 2852   $95.00               2                104                  4.79
# 2853   $91.00               2                 29                  5.00
# 2854  $299.00               3                 35                  4.94
# 2855  $175.00               2                 90                  4.97
#
#       availability_365 instant_bookable        id  \
# 0                  285                f    108061
# 1                  179                t    155305
# 2                    0                t    156805
# 3                  199                t    156926
# 4                   78                f    197263
# ...                ...              ...       ...
# 2851               354                t  51838711
# 2852               168                t  20910203
# 2853               169                t  40617579
# 2854               237                t  47531339
# 2855               286                f  48198661
#
#                                 listing_url       scrape_id last_scraped  \
# 0       https://www.airbnb.com/rooms/108061  20220611041116   2022-06-11
# 1       https://www.airbnb.com/rooms/155305  20220611041116   2022-06-11
# 2       https://www.airbnb.com/rooms/156805  20220611041116   2022-06-11
# 3       https://www.airbnb.com/rooms/156926  20220611041116   2022-06-11
# 4       https://www.airbnb.com/rooms/197263  20220611041116   2022-06-11
# ...                                     ...             ...          ...
# 2851  https://www.airbnb.com/rooms/51838711  20220611041116   2022-06-11
# 2852  https://www.airbnb.com/rooms/20910203  20220611041116   2022-06-11
# 2853  https://www.airbnb.com/rooms/40617579  20220611041116   2022-06-11
# 2854  https://www.airbnb.com/rooms/47531339  20220611041116   2022-06-11
# 2855  https://www.airbnb.com/rooms/48198661  20220611041116   2022-06-11
#
#                                                    name  \
# 0     Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                    Cottage! BonPaul + Sharky's Hostel
# 2                     Private Room "Ader" at BPS Hostel
# 3                Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4                          Tranquil Room & Private Bath
# ...                                                 ...
# 2851                 Rustic Camper minutes to Asheville
# 2852                           Mountain Cottage Retreat
# 2853  Relaxing country home right outside of Asheville.
# 2854                        Barefoot Lodge at Dix Creek
# 2855               Asheville views for miles, Brand new
#
#                                             description
# 0     Walk to town in ten minutes! Monthly rental in...
# 1     <b>The space</b><br />Private cottage located ...
# 2     <b>The space</b><br />Private Rooms at Bon Pau...
# 3     This is a top bunk in the mixed dorm room<br /...
# 4     This is a comfy, peaceful and clean room with ...
# ...                                                 ...
# 2851  Rustic, cozy, camper with lots of wood detaili...
# 2852  Cozy guest cottage in prime location for visit...
# 2853  A quiet country home just 15 minutes away from...
# 2854  Private cabin in rolling landscape that's 15 m...
# 2855  Charming cabin with amazing mountain views. Br...
#
# [2856 rows x 21 columns]

# %% [markdown]
# #### Basic info

# %%
df.shape
# Out:
# (2856, 21)

# %% [markdown]
# #### Pre-cleaning

# %% [markdown]
# ##### Duplicated

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2851    False
# 2852    False
# 2853    False
# 2854    False
# 2855    False
# Length: 2856, dtype: bool

# %%
nb_duplicated_rows = df.duplicated().sum()
nb_duplicated_rows
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ##### Price as a float

# %% [markdown]
# *For one price...*

# %%
df["price"][0]
# Out:
# '$120.00'

# %%
type(df["price"][0])
# Out:
# str

# %%
df["price"][0]*10
# Out:
# '$120.00$120.00$120.00$120.00$120.00$120.00$120.00$120.00$120.00$120.00'

# %%
float(df["price"][0].replace("$",""))
# Out:
# 120.0

# %%
float(df["price"][0].replace("$",""))*15
# Out:
# 1800.0

# %% [markdown]
# *For the entire "price" column...*

# %%
df["price"] = df["price"].str.replace("$", "").str.replace(",", "").astype(float)
# Out:
# /var/folders/6p/s5dyg_x13_zbgfd_xsyg3s7c0000gn/T/ipykernel_24275/293166301.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["price"] = df["price"].str.replace("$", "").str.replace(",", "").astype(float)

# %% [markdown]
# ##### Affordable accommodations

# %%
sns.histplot(data = df, x="price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
round(df["price"].describe())
# Out:
# count     2856.0
# mean       196.0
# std        491.0
# min         19.0
# 25%         98.0
# 50%        140.0
# 75%        225.0
# max      24999.0
# Name: price, dtype: float64

# %% [markdown]
# Focus on affordable accomodations for your predictions.

# %%
lower_budget = 50
upper_budget = 800

# %%
davys_filter = (df["price"] >= lower_budget) & (df["price"] <= upper_budget)
davys_filter
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2851    False
# 2852     True
# 2853     True
# 2854     True
# 2855     True
# Name: price, Length: 2856, dtype: bool

# %%
df = df[davys_filter]

# %%
sns.histplot(data = df, x="price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ##### Missing values - First glimpse

# %%
# percentage of missing values
# df.isna().sum().sort_values(ascending=False)/len(df)

round(df.isna().mean().sort_values(ascending=False),2)
# Out:
# review_scores_rating      0.06
# bedrooms                  0.05
# beds                      0.01
# description               0.00
# name                      0.00
# last_scraped              0.00
# scrape_id                 0.00
# listing_url               0.00
# id                        0.00
# instant_bookable          0.00
# availability_365          0.00
# neighbourhood_cleansed    0.00
# number_of_reviews         0.00
# latitude                  0.00
# price                     0.00
# bathrooms_text            0.00
# accommodates              0.00
# room_type                 0.00
# property_type             0.00
# longitude                 0.00
# minimum_nights            0.00
# dtype: float64

# %%
df["bathrooms_text"].unique()
# Out:
# array(['1 bath', '2.5 shared baths', '1 shared bath', '1.5 baths',
#        '1 private bath', '2.5 baths', '2 baths', '2 shared baths',
#        '3 baths', '1.5 shared baths', '3.5 baths', '0 shared baths',
#        '4.5 baths', '0 baths', '4 baths', 'Half-bath', '7 baths',
#        '5 baths', '5.5 baths', '6 baths'], dtype=object)

# %%
trysomething = '2.5 shared baths'

# %%
float(trysomething.split()[0])
# Out:
# 2.5

# %%
def bathroom_number_extractor(silly_text):
    if silly_text == "Half-bath":
        return 0.5
    else:
        return float(silly_text.split()[0])

# %%
df["nb_bathrooms"] = df["bathrooms_text"].apply(bathroom_number_extractor)
df.drop(columns=["bathrooms_text"], inplace = True)
# Out:
# /var/folders/6p/s5dyg_x13_zbgfd_xsyg3s7c0000gn/T/ipykernel_24275/2669365527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nb_bathrooms"] = df["bathrooms_text"].apply(bathroom_number_extractor)
# /var/folders/6p/s5dyg_x13_zbgfd_xsyg3s7c0000gn/T/ipykernel_24275/2669365527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["bathrooms_text"], inplace = True)

# %%
df["instant_bookable"] = df["instant_bookable"].map({"f":False, 
                                                     "t":True})
# Out:
# /var/folders/6p/s5dyg_x13_zbgfd_xsyg3s7c0000gn/T/ipykernel_24275/1216166316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["instant_bookable"] = df["instant_bookable"].map({"f":False,

# %% [markdown]
# #### Selecting features manually

# %%
df["room_type"].value_counts()
# Out:
# Entire home/apt    2391
# Private room        336
# Hotel room           15
# Shared room           1
# Name: room_type, dtype: int64

# %%
df.head(3)
# Out:
#    neighbourhood_cleansed  latitude  longitude         property_type  \
# 0                   28801  35.60670  -82.55563    Entire rental unit
# 1                   28806  35.57864  -82.59578     Entire guesthouse
# 2                   28806  35.57864  -82.59578  Private room in home
#
#          room_type  accommodates  bedrooms  beds  price  minimum_nights  \
# 0  Entire home/apt             2       1.0   1.0  120.0              30
# 1  Entire home/apt             2       1.0   1.0  100.0               1
# 2     Private room             2       1.0   1.0   66.0               1
#
#    number_of_reviews  review_scores_rating  availability_365 instant_bookable  \
# 0                 90                  4.50               285                f
# 1                359                  4.58               179                t
# 2                 67                  4.52                 0                t
#
#        id                          listing_url       scrape_id last_scraped  \
# 0  108061  https://www.airbnb.com/rooms/108061  20220611041116   2022-06-11
# 1  155305  https://www.airbnb.com/rooms/155305  20220611041116   2022-06-11
# 2  156805  https://www.airbnb.com/rooms/156805  20220611041116   2022-06-11
#
#                                                 name  \
# 0  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                 Cottage! BonPaul + Sharky's Hostel
# 2                  Private Room "Ader" at BPS Hostel
#
#                                          description  nb_bathrooms
# 0  Walk to town in ten minutes! Monthly rental in...           1.0
# 1  <b>The space</b><br />Private cottage located ...           1.0
# 2  <b>The space</b><br />Private Rooms at Bon Pau...           2.5

# %%
df.columns
# Out:
# Index(['neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'number_of_reviews', 'review_scores_rating',
#        'availability_365', 'instant_bookable', 'id', 'listing_url',
#        'scrape_id', 'last_scraped', 'name', 'description', 'nb_bathrooms'],
#       dtype='object')

# %%
selected_columns = [
    "room_type",
    "accommodates",
    "nb_bathrooms",
    "bedrooms",
    "beds",
    "minimum_nights",
    "number_of_reviews",
    "review_scores_rating",
    "availability_365",
    "instant_bookable",
    "price"
]

df = df[selected_columns]

# %% [markdown]
# #### Pre-cleaning in one single function

# %%
def df_pre_cleaning(df):
    # Convert price from string to float
    df["price"] = df["price"].str.replace("$", "").str.replace(",", "").astype(float)
    # Affordable
    lower_budget = 50
    upper_budget = 800
    davys_filter = (df["price"] >= lower_budget) & (df["price"] <= upper_budget)
    df = df[davys_filter]
    # Number of Bathrooms
    df["nb_bathrooms"] = df["bathrooms_text"].apply(bathroom_number_extractor)
    # Instant bookable
    df["instant_bookable"] = df["instant_bookable"].map({"f":False, 
                                                     "t":True})    
    # Selecting columns of interest
    selected_columns = [
        "room_type",
        "accommodates",
        "nb_bathrooms",
        "bedrooms",
        "beds",
        "minimum_nights",
        "number_of_reviews",
        "review_scores_rating",
        "availability_365",
        "instant_bookable",
        "price"
    ]

    df = df[selected_columns]
    return df

# %%
# df_onemoretime = pd.read_csv(airbnb_asheville, index_col = 0)
# df_onemoretime_precleaned = df_pre_cleaning(df_onemoretime)
# df_onemoretime_precleaned

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Scaling the numerical features

# %% [markdown]
# #### Encoding the categorical features

# %% [markdown]
# #### Final Preprocessor

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Train-Test Split

# %% [markdown]
# #### Transform data

# %% [markdown]
# #### Linear Regression

# %% [markdown]
# #### Trying all the models!
