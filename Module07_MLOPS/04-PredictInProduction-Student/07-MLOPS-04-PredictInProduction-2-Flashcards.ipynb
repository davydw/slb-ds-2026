# %% [markdown]
# # 07-MLOPS-04-PredictInProduction-2-Flashcards.ipynb

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>

# %% [markdown]
# <details>
#     <summary>Q</summary>
# A
# </details>
