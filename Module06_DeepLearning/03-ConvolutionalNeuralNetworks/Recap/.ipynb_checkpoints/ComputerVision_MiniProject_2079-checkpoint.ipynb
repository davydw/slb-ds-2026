# %% [markdown]
# # 🐱 🐶 A mini CNN project about cats and dogs...

# %% [markdown]
# ## 📚 Libraries

# %%
# DATA MANIPULATION
import numpy as np
# DATA VIZ
import matplotlib.pyplot as plt

# IMAGE PROCESSING AND LOADER
from keras.preprocessing.image import load_img, img_to_array
from keras.preprocessing import image_dataset_from_directory

# NEURAL NETWORKS
from keras import models, Input, layers, optimizers, callbacks

# PRE-TRAINED MODEL
from keras.applications.vgg16 import VGG16

# %% [markdown]
# ## 🛠️ Utils

# %%
def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

# %%
def plot_compare_history(history, name_history, history_1, name_history_1):

    fig, ax = plt.subplots(1, 2, figsize=(15,5))

    ax[0].set_title('loss')

    ax[0].plot(history.epoch, history.history["loss"], label="Train loss " + name_history)
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss " + name_history)

    ax[0].plot(history_1.epoch, history_1.history["loss"], label="Train loss " + name_history_1)
    ax[0].plot(history_1.epoch, history_1.history["val_loss"], label="Validation loss " + name_history_1)

    ax[1].set_title('Accuracy')

    ax[1].plot(history.epoch, history.history["accuracy"], label="Train Accuracy " + name_history)
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy " + name_history)

    ax[1].plot(history_1.epoch, history_1.history["accuracy"], label="Train Accuracy " + name_history_1)
    ax[1].plot(history_1.epoch, history_1.history["val_accuracy"], label="Validation Accuracy " + name_history_1)

    ax[0].legend()
    ax[1].legend()

# %% [markdown]
# ## 💾 Load Dataset

# %% [markdown]
# * This Dataset contains about 5000 pictures of cats and dogs (4000 for training and 1000 for testing).
# * Each category will be in a separated folder, `cat-and-dog/training_set/` and `cat-and-dog/test_set` and then in sub folders `cats` and `dogs`.

# %%
# !curl "https://wagon-public-datasets.s3.amazonaws.com/deep_learning_datasets/cat-and-dog.zip" --output cat-and-dog.zip
# !unzip -qn cat-and-dog.zip

# %%
# !ls
# Out:
# cat-and-dog-small                     ComputerVision_MiniProject_2007.ipynb
# cat-and-dog.zip                       README.md
# computer_vision.ipynb

# %%
# !tree -L 3
# Out:
# .
# ├── cat-and-dog-small
# │   ├── test_set
# │   │   ├── cats
# │   │   └── dogs
# │   └── training_set
# │       ├── cats
# │       └── dogs
# ├── cat-and-dog.zip
# ├── computer_vision.ipynb
# ├── ComputerVision_MiniProject_2007.ipynb
# └── README.md
#
# 8 directories, 4 files

# %%
train_data_dir = "cat-and-dog-small/training_set/"
test_data_dir = "cat-and-dog-small/test_set/"

# %% [markdown]
# ## 👀 Explore Dataset

# %%
path_train_cat_3 = f"{train_data_dir}cats/cat.3.jpg"

# %%
img_train_cat_3 = load_img(path_train_cat_3)

# %%
type(img_train_cat_3)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_train_cat_3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x414>

# %%
x_train_cat_3 = img_to_array(img_train_cat_3)/255.

# %%
type(x_train_cat_3)
# Out:
# numpy.ndarray

# %%
x_train_cat_3.shape
# Out:
# (414, 500, 3)

# %%
# x_train_cat_3

# %% [markdown]
# ## 🗂️ "Features" (Images) & "Target" (Folder name)

# %%
BATCH_SIZE = 64

train_ds = image_dataset_from_directory(
    train_data_dir,
    labels = "inferred",
    label_mode = "binary",
    image_size = (224,224),
    batch_size = BATCH_SIZE
)

val_ds = image_dataset_from_directory(
    test_data_dir,
    labels = "inferred",
    label_mode = "binary",
    image_size = (224,224),
    batch_size = BATCH_SIZE
)
# Out:
# Found 4010 files belonging to 2 classes.
# Found 1012 files belonging to 2 classes.

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.prefetch_op._PrefetchDataset

# %%
train_ds.class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# ## 🧠 CNN

# %% [markdown]
# ### (1) Model V1

# %%
def first_model():

    # 1 - ARCHITECTURE

    model = models.Sequential([
        ### INPUT LAYER
        Input(shape=(224,224,3)),

        ### SCALING
        layers.Rescaling(1/255.),
        ### CONVOLUTIONS
        ###### CONV no. 1
        layers.Conv2D(filters=32, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 2
        layers.Conv2D(filters=32, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 3
        layers.Conv2D(filters=64, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 4
        layers.Conv2D(filters=128, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ### FLATTEN
        layers.Flatten(),
        ### SOME HIDDEN DENSE LAYERS
        layers.Dense(64, activation="relu"),
        ### PREDICTIVE/OUTPUT LAYER
        layers.Dense(1, activation="sigmoid")


    ])

    # 2 - COMPILE
    my_adam = optimizers.Adam(learning_rate = 0.002)

    model.compile(loss="binary_crossentropy", #"categorical_crossentropy"
                  optimizer = my_adam,        #"sparse_categorical_crossentropy"
                  metrics = ["accuracy"])


    return model

# %%
first_model = first_model()

MODEL = "model_1.keras"

modelCheckpoint = callbacks.ModelCheckpoint(MODEL,
                                            monitor="val_loss",
                                            verbose=0,
                                            save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss",
                                        factor=0.1,
                                        patience=3,
                                        verbose=1,
                                        min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss',
                                       patience=10,
                                       verbose=0,
                                       restore_best_weights=True)

history_1 = first_model.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks=[modelCheckpoint, LRreducer, EarlyStopper]
        )
# Out:
# Epoch 1/30
# 2025-05-23 18:21:29.223472: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.5117 - loss: 0.9036 - val_accuracy: 0.5020 - val_loss: 0.7603 - learning_rate: 0.0020
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.4998 - loss: 0.7481 - val_accuracy: 0.5425 - val_loss: 0.7187 - learning_rate: 0.0020
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5228 - loss: 0.7240 - val_accuracy: 0.5445 - val_loss: 0.6916 - learning_rate: 0.0020
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.5276 - loss: 0.7030 - val_accuracy: 0.5484 - val_loss: 0.6865 - learning_rate: 0.0020
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5184 - loss: 0.7084 - val_accuracy: 0.5099 - val_loss: 0.7097 - learning_rate: 0.0020
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5372 - loss: 0.6960 - val_accuracy: 0.5267 - val_loss: 0.6977 - learning_rate: 0.0020
# Epoch 7/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5389 - loss: 0.6994
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5388 - loss: 0.6996 - val_accuracy: 0.5296 - val_loss: 0.8240 - learning_rate: 0.0020
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5222 - loss: 0.7640 - val_accuracy: 0.5148 - val_loss: 0.7243 - learning_rate: 2.0000e-04
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5313 - loss: 0.7155 - val_accuracy: 0.5820 - val_loss: 0.6891 - learning_rate: 2.0000e-04
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5709 - loss: 0.6828 - val_accuracy: 0.6047 - val_loss: 0.6697 - learning_rate: 2.0000e-04
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6082 - loss: 0.6630 - val_accuracy: 0.6156 - val_loss: 0.6564 - learning_rate: 2.0000e-04
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6326 - loss: 0.6544 - val_accuracy: 0.6344 - val_loss: 0.6458 - learning_rate: 2.0000e-04
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6448 - loss: 0.6361 - val_accuracy: 0.6512 - val_loss: 0.6455 - learning_rate: 2.0000e-04
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6671 - loss: 0.6273 - val_accuracy: 0.6680 - val_loss: 0.6369 - learning_rate: 2.0000e-04
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6813 - loss: 0.6148 - val_accuracy: 0.6591 - val_loss: 0.6646 - learning_rate: 2.0000e-04
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.6742 - loss: 0.6200 - val_accuracy: 0.6383 - val_loss: 0.6443 - learning_rate: 2.0000e-04
# Epoch 17/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6719 - loss: 0.6071
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6724 - loss: 0.6067 - val_accuracy: 0.6532 - val_loss: 0.6400 - learning_rate: 2.0000e-04
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6921 - loss: 0.5785 - val_accuracy: 0.6700 - val_loss: 0.6367 - learning_rate: 2.0000e-05
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7017 - loss: 0.5786 - val_accuracy: 0.6670 - val_loss: 0.6377 - learning_rate: 2.0000e-05
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6914 - loss: 0.5876 - val_accuracy: 0.6729 - val_loss: 0.6384 - learning_rate: 2.0000e-05
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7024 - loss: 0.5782
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.0000001313746906e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7025 - loss: 0.5781 - val_accuracy: 0.6690 - val_loss: 0.6383 - learning_rate: 2.0000e-05
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6995 - loss: 0.5809 - val_accuracy: 0.6690 - val_loss: 0.6381 - learning_rate: 2.0000e-06
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6984 - loss: 0.5804 - val_accuracy: 0.6680 - val_loss: 0.6381 - learning_rate: 2.0000e-06
# Epoch 24/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6979 - loss: 0.5784
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.000000222324161e-07.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6983 - loss: 0.5779 - val_accuracy: 0.6690 - val_loss: 0.6380 - learning_rate: 2.0000e-06
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7051 - loss: 0.5748 - val_accuracy: 0.6690 - val_loss: 0.6380 - learning_rate: 2.0000e-07
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7028 - loss: 0.5701 - val_accuracy: 0.6690 - val_loss: 0.6380 - learning_rate: 2.0000e-07
# Epoch 27/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7039 - loss: 0.5702
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.000000165480742e-08.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7041 - loss: 0.5699 - val_accuracy: 0.6700 - val_loss: 0.6380 - learning_rate: 2.0000e-07
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6982 - loss: 0.5786 - val_accuracy: 0.6700 - val_loss: 0.6380 - learning_rate: 2.0000e-08

# %%
plot_history(history_1)

# %% [markdown]
# ### (2) Model V2 with Data Augmentation

# %%
def second_model():

    # 1 - ARCHITECTURE

    model = models.Sequential([
        ### INPUT LAYER
        Input(shape=(224,224,3)),

        ### SCALING
        layers.Rescaling(1/255.),

        ### NEW !!!! DATA AUGMENTATION
        layers.RandomFlip("horizontal"),
        # layers.RandomFlip("vertical"),
        # layers.RandomZoom(2),
        layers.RandomZoom(0.1),
        #layers.RandomTranslation((0.2, 0.2)),
        layers.RandomRotation(0.1),

        ### CONVOLUTIONS
        ###### CONV no. 1
        layers.Conv2D(filters=32, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 2
        layers.Conv2D(filters=32, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 3
        layers.Conv2D(filters=64, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),
        ###### CONV no. 4
        layers.Conv2D(filters=128, kernel_size = (3,3), activation="relu"),
        layers.MaxPool2D(pool_size=(2,2)),

        ### FLATTEN
        layers.Flatten(),
        ### SOME HIDDEN DENSE LAYERS
        layers.Dense(64, activation="relu"),
        ### PREDICTIVE/OUTPUT LAYER
        layers.Dense(1, activation="sigmoid")


    ])

    # 2 - COMPILE
    my_adam = optimizers.Adam(learning_rate = 0.002)

    model.compile(loss="binary_crossentropy", #"categorical_crossentropy"
                  optimizer = my_adam,        #"sparse_categorical_crossentropy"
                  metrics = ["accuracy"])


    return model

# %%
second_model = second_model()

MODEL = "model_2.keras"

modelCheckpoint = callbacks.ModelCheckpoint(MODEL,
                                            monitor="val_loss",
                                            verbose=0,
                                            save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss",
                                        factor=0.1,
                                        patience=3,
                                        verbose=1,
                                        min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss',
                                       patience=10,
                                       verbose=0,
                                       restore_best_weights=True)

# %%
history_2 = second_model.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper]
        )
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.4931 - loss: 0.7305 - val_accuracy: 0.5000 - val_loss: 0.6933 - learning_rate: 0.0020
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.4918 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0020
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.4873 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0020
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.4939 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0020
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4943 - loss: 0.6932
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.4943 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0020
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.4883 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.4931 - loss: 0.6932 - val_accuracy: 0.4990 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4860 - loss: 0.6932
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.4860 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.4868 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-05
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.4930 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-05
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4943 - loss: 0.6932
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.0000001313746906e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.4944 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-05
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.4966 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-06
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.4990 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-06
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4936 - loss: 0.6932
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.000000222324161e-07.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-06
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.4964 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-07
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.4939 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.0000e-07

# %%
plot_history(history_2)

# %%
plot_compare_history(history_1, "Basic CNN", history_2, "Data Augmentation")

# %% [markdown]
# ### (3) Model V3 with Transfer Learning

# %%
# vgg16 = VGG16(include_top = False, weights="imagenet", input_shape=(224,224,3))
# vgg16.trainable = False
# vgg16.summary()

# %%
def my_customized_vgg16():
    # PRETRAINED LAYERS
    vgg16 = VGG16(include_top = False, weights="imagenet", input_shape=(224,224,3))
    vgg16.trainable = False
    # MY LAYERS
    flatten = layers.Flatten()
    dense_1 = layers.Dense(32, activation="relu")
    dropout_1 = layers.Dropout(0.3)
    dense_2 = layers.Dense(16, activation="relu")
    dropout_2 = layers.Dropout(0.3)
    predictive = layers.Dense(1, "sigmoid")

    model = models.Sequential([
        vgg16,
        flatten,
        dense_1,
        dropout_1,
        dense_2,
        dropout_2,
        predictive
    ])

    # 2 - COMPILE
    my_adam = optimizers.Adam(learning_rate = 0.002)

    model.compile(loss="binary_crossentropy", #"categorical_crossentropy"
                  optimizer = my_adam,        #"sparse_categorical_crossentropy"
                  metrics = ["accuracy"])


    return model

# %%
third_model = my_customized_vgg16()
third_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │       802,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,518,081 (59.20 MB)
#  Trainable params: 803,393 (3.06 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
third_model = my_customized_vgg16()

MODEL = "model_3.keras"

modelCheckpoint = callbacks.ModelCheckpoint(MODEL,
                                            monitor="val_loss",
                                            verbose=0,
                                            save_best_only=True)

LRreducer = callbacks.ReduceLROnPlateau(monitor="val_loss",
                                        factor=0.1,
                                        patience=3,
                                        verbose=1,
                                        min_lr=0)

EarlyStopper = callbacks.EarlyStopping(monitor='val_loss',
                                       patience=10,
                                       verbose=0,
                                       restore_best_weights=True)

history_3 = third_model.fit(
        train_ds,
        epochs=30,
        validation_data=val_ds,
        callbacks = [modelCheckpoint, LRreducer, EarlyStopper])
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 338ms/step - accuracy: 0.5852 - loss: 292.3551 - val_accuracy: 0.9684 - val_loss: 10.8910 - learning_rate: 0.0020
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 337ms/step - accuracy: 0.8945 - loss: 81.1387 - val_accuracy: 0.9674 - val_loss: 19.7720 - learning_rate: 0.0020
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 329ms/step - accuracy: 0.9564 - loss: 26.1296 - val_accuracy: 0.9694 - val_loss: 21.5294 - learning_rate: 0.0020
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9655 - loss: 23.9447
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 326ms/step - accuracy: 0.9656 - loss: 23.8645 - val_accuracy: 0.9704 - val_loss: 21.9194 - learning_rate: 0.0020
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 319ms/step - accuracy: 0.9775 - loss: 11.1999 - val_accuracy: 0.9733 - val_loss: 21.9524 - learning_rate: 2.0000e-04
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 315ms/step - accuracy: 0.9766 - loss: 10.7198 - val_accuracy: 0.9713 - val_loss: 22.1586 - learning_rate: 2.0000e-04
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9817 - loss: 8.0162
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 317ms/step - accuracy: 0.9817 - loss: 8.0451 - val_accuracy: 0.9713 - val_loss: 22.2938 - learning_rate: 2.0000e-04
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 317ms/step - accuracy: 0.9788 - loss: 8.9248 - val_accuracy: 0.9713 - val_loss: 22.3125 - learning_rate: 2.0000e-05
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 314ms/step - accuracy: 0.9802 - loss: 10.2735 - val_accuracy: 0.9713 - val_loss: 22.3166 - learning_rate: 2.0000e-05
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9882 - loss: 6.6341
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.0000001313746906e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 319ms/step - accuracy: 0.9881 - loss: 6.6605 - val_accuracy: 0.9713 - val_loss: 22.3515 - learning_rate: 2.0000e-05
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 318ms/step - accuracy: 0.9765 - loss: 10.8693 - val_accuracy: 0.9713 - val_loss: 22.3507 - learning_rate: 2.0000e-06

# %%
plot_history(history_3)

# %%
plot_compare_history(history_1, "Basic CNN", history_3, "Transfer Learning")

# %% [markdown]
# ## 🔮 Predictions

# %%
from PIL import Image
import requests
from io import BytesIO

def getImage(url):
    '''Grabs an image based on its URL, and resize it
    '''
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    img = img.resize((224, 224))
    return img

def predictImage(url, model):
    '''Takes an image and a model
    '''
    img = getImage(url)
    img = img_to_array(img)
    img = img.reshape((-1, 224, 224, 3))
    res = model.predict(img)[0][0]
    if(res < 0.5):
        animal = "cat"
        prob = 1-res
    if(res >= 0.5):
        animal = "dog"
        prob = res

    print("Animal : ", animal)
    print("probability = ",prob)

# %%
cat = "https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg"
cat
# Out:
# 'https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg'

# %%
predictImage(cat, third_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# Animal :  cat
# probability =  1.0

# %%
dog = "https://images.sudouest.fr/2018/04/14/5ace461a66a4bd2b1780a0dd/widescreen/1000x500/on-ignore-si-le-chihuahua-a-deserte-ou-non-les-locaux-de-la-clinique.jpg?v1"
dog
# Out:
# 'https://images.sudouest.fr/2018/04/14/5ace461a66a4bd2b1780a0dd/widescreen/1000x500/on-ignore-si-le-chihuahua-a-deserte-ou-non-les-locaux-de-la-clinique.jpg?v1'

# %%
predictImage(dog, third_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Animal :  dog
# probability =  1.0
