# %% [markdown]
# #### Requirements

# %%
# Run this cell to install some required packages:
# !pip install keras-nlp pydot bertviz
# Out:
# Requirement already satisfied: keras-nlp in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (0.19.0)
# Requirement already satisfied: pydot in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (4.0.0)
# Requirement already satisfied: bertviz in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: keras-hub==0.19.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-nlp) (0.19.0)
# Requirement already satisfied: keras>=3.5 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (3.8.0)
# Requirement already satisfied: absl-py in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (2.1.0)
# Requirement already satisfied: numpy in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (1.26.4)
# Requirement already satisfied: packaging in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (24.2)
# Requirement already satisfied: regex in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (2024.11.6)
# Requirement already satisfied: rich in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (13.9.4)
# Requirement already satisfied: kagglehub in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras-hub==0.19.0->keras-nlp) (0.3.9)
# Requirement already satisfied: pyparsing>=3.0.9 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from pydot) (3.2.1)
# Requirement already satisfied: transformers>=2.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (4.49.0)
# Requirement already satisfied: torch>=1.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (2.6.0)
# Requirement already satisfied: tqdm in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (4.67.1)
# Requirement already satisfied: boto3 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (1.38.24)
# Requirement already satisfied: requests in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (2.32.3)
# Requirement already satisfied: sentencepiece in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from bertviz) (0.2.0)
# Requirement already satisfied: namex in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras>=3.5->keras-hub==0.19.0->keras-nlp) (0.0.8)
# Requirement already satisfied: h5py in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras>=3.5->keras-hub==0.19.0->keras-nlp) (3.13.0)
# Requirement already satisfied: optree in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras>=3.5->keras-hub==0.19.0->keras-nlp) (0.14.0)
# Requirement already satisfied: ml-dtypes in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from keras>=3.5->keras-hub==0.19.0->keras-nlp) (0.3.2)
# Requirement already satisfied: filelock in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (4.12.2)
# Requirement already satisfied: networkx in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (3.1.5)
# Requirement already satisfied: fsspec in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (2025.2.0)
# Requirement already satisfied: setuptools in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from torch>=1.0->bertviz) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.0->bertviz) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from transformers>=2.0->bertviz) (0.29.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from transformers>=2.0->bertviz) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from transformers>=2.0->bertviz) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from transformers>=2.0->bertviz) (0.5.2)
# Requirement already satisfied: botocore<1.39.0,>=1.38.24 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from boto3->bertviz) (1.38.24)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from boto3->bertviz) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from boto3->bertviz) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.24->boto3->bertviz) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.24->boto3->bertviz) (2.3.0)
# Requirement already satisfied: six>=1.5 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.24->boto3->bertviz) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from jinja2->torch>=1.0->bertviz) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests->bertviz) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests->bertviz) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from requests->bertviz) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from rich->keras-hub==0.19.0->keras-nlp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from rich->keras-hub==0.19.0->keras-nlp) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/davywai/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras-hub==0.19.0->keras-nlp) (0.1.2)

# %% [markdown]
# # Visualizing the flow of a model

# %% [markdown]
# ### Demonstrating projection

# %%
from keras_nlp.layers import TokenAndPositionEmbedding
from tensorflow.keras.layers import Input, LayerNormalization, Dense, Embedding
from tensorflow.keras import Sequential, Model
import tensorflow as tf

# Imagine an input sequence of 10 tokens
input_layer = Input(shape = (10,), name = "sequence_of_10_tokens")
# This layer takes our tokens and gives them both word and pos embeddings
embedding_layer = TokenAndPositionEmbedding(20, 10, 768, name = "pos_and_token_embedding")(input_layer)

# For visualization purposes
first_embeddings = Model(inputs = input_layer, outputs = embedding_layer)
tf.keras.utils.plot_model(first_embeddings,  show_shapes=True, show_layer_names=True)
# Out:
# 2025-05-28 22:23:46.738170: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-05-28 22:23:46.738224: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-05-28 22:23:46.738235: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-05-28 22:23:46.738433: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-28 22:23:46.738451: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Demonstrating passing to FFN

# %%
# # Queries x Keys
# dot_product = tf.matmul(query, key, transpose_b=True, name = "dot_product_q_k")
# # Scale
# scaled_dot_product = dot_product / 768 ** 0.5
# # Softmax
# softmaxed = tf.nn.softmax(scaled_dot_product, name = "apply_softmax")
# # Multiply by Values
# z = tf.matmul(softmaxed, value, name = "multiply_scores_w_value")

# # For visualization purposes
# partial_block = Model(inputs = input_layer, outputs = z)


import tensorflow as tf
from keras.layers import Input, Embedding, Dense, Dot, Softmax
from keras.models import Model

# Toy hyper-params
seq_len     = 10          # length of the input sentence
vocab_size  = 50          # let's assume
d_model     = 768         # projection size = dₖ = dᵥ = 768 in your snippet

# ----- model -----
input_layer      = Input(shape=(seq_len,), dtype="int32", name="sequence_of_10_tokens")
embedding_layer  = Embedding(vocab_size, d_model, name="token_embedding")(input_layer)

# Q, K, V projections
query  = Dense(d_model, name="query_projection")(embedding_layer)   # (batch, L, dₖ)
key    = Dense(d_model, name="key_projection")(embedding_layer)     # (batch, L, dₖ)
value  = Dense(d_model, name="value_projection")(embedding_layer)   # (batch, L, dᵥ)

print(f"The shape of query is {query.shape}.")
print(f"The shape of key is {key.shape}.")
print(f"The shape of value is {value.shape}.")
# Out:
# The shape of query is (None, 10, 768).
# The shape of key is (None, 10, 768).
# The shape of value is (None, 10, 768).

# %%
#########################
# SIMILARITY SCORES     #
#########################

# 1️⃣  Dot product Q · Kᵀ   (no explicit transpose needed)
dot_product = Dot(axes=(2, 2),              # contract the dₖ axis of each tensor
                  name="dot_product_q_k")([query, key])
# dot_product = tf.matmul(query, key, transpose_b=True, name = "dot_product_q_k")
# → shape: (batch, L_q, L_k)  ==  (batch, L, L)

# 2️⃣  Scale by √dₖ
d_k =  tf.cast(query.shape[-1], tf.float32)  # == 2 here
scaled = dot_product / tf.math.sqrt(d_k)

# 3️⃣  Softmax over the key dimension (last axis)
attention_scores = Softmax(axis=-1, name="apply_softmax")(scaled)

#########################
# INFORMATION RETRIEVAL #
#########################

# 4️⃣  Scores × V   → Z
z = Dot(axes=(2, 1),               # contract L_k/L_v axis
        name="multiply_scores_w_value")([attention_scores, value])
# → shape: (batch, L_q, dᵥ) == (batch, L, 2)

# For visualisation / further stacking
partial_block = Model(inputs=input_layer, outputs=z)

tf.keras.utils.plot_model(partial_block,  show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Putting it all together

# %%
# Then we simply add some Dense layers and normalization
ff_1 = Dense(4 * 768, name = "first_feed_forward")(z)
ff_2 = Dense(768, name = "second_feed_forward")(ff_1)
ffn_output = tf.keras.layers.LayerNormalization(name = "normalize_mean_0_std_1")(ff_2)

# For visualization purposes
full_block = Model(inputs = input_layer, outputs = ffn_output)
tf.keras.utils.plot_model(full_block,  show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Visualization with BertViz

# %%
from bertviz import head_view
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained("bert-base-uncased", output_attentions = True)

first_sentence = "The lawyer worked on the case"
second_sentence = "I pushed shift to make the letters upper case"

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
viz_input = tokenizer(first_sentence, second_sentence, return_tensors = "pt")
attention = model(**viz_input).attentions
starter = (viz_input.token_type_ids == 0).sum(dim = 1)
tokens = tokenizer.convert_ids_to_tokens(viz_input.input_ids[0])
head_view(attention, tokens, starter, heads = [8])

# %% [markdown]
# # `transformers` pipelines

# %%
from transformers import pipeline
pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-en-fr")

# %%
result = pipe("I am a student and I am studying in London")
result[0]['translation_text']

# %% [markdown]
# ### Pipelines under the hood (a Tensorflow variation)

# %%
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

tokens = tokenizer.encode("This is easy!", return_tensors = "tf")

print(tokens)

# %%
model = TFAutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr", from_pt = True)

output_tokens = model.generate(tokens)

print(output_tokens)

print(tokenizer.decode(output[0]))
